# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
WineQualityDf = pd.read_csv("../data/WineQualityDf_cleaned.csv")
WineQualityDf
# Out:
#       Unnamed: 0  fixed acidity  volatile acidity  citric acid  \
# 0              0            7.4             0.700         0.00
# 1              1            7.8             0.880         0.00
# 2              2            7.8             0.760         0.04
# 3              3           11.2             0.280         0.56
# 4              5            7.4             0.660         0.00
# ...          ...            ...               ...          ...
# 1354        1593            6.8             0.620         0.08
# 1355        1594            6.2             0.600         0.08
# 1356        1595            5.9             0.550         0.10
# 1357        1597            5.9             0.645         0.12
# 1358        1598            6.0             0.310         0.47
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0                1.9      0.076                 11.0                  34.0
# ...

# %%
sns.pairplot(WineQualityDf)
plt.show()

# %% [markdown]
# # Linearity bewtween variables visually checked
